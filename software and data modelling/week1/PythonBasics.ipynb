# %% [markdown]
# # Python Language Basics
#
# o Python uses whitespace (tabs or spaces) to structure code instead of using braces
#
# o Text preceded by the hash mark (pound sign) # is considered comment code and is ignored by the Python interpreter.
#
# o Indentation used instead of braces
#
# o Colon denotes the start of an indented code block after which all of the code must be identically indented
#
# o Function and object method structure and calls nearly identical to other popular languages
#
# o Everything is an object
#
# o Almost every object in Python has attached methods that have access to the object’s internal contents
#
# o Primitive data types such as number and strings use call-by-value parameter passing
#
# o Strings are immutable in Python
#
# o Lists and objects are use call-by-reference parameter passing
#
# o Lists
#
#     - Python does not have an array type but lists can be used to mimic arrays
#     - Lists are mutable
#     - Data items can be of different type
#     - The first element in a Python list is the zeroth element.
#
# o if, elif, and else used for selection structures
#
# o for and while are used for repetition structure
#
# REFERENCE: https://www.w3schools.com/python/

# %%
x = eval(input('enter a number: '))
if x < 0:
   print('It\'s negative')
elif x == 0:
   print('Equal to zero')
elif x < 5:
   print('Positive but smaller than 5')
else:
   print('Positive and larger than or equal to 5')

sequence = [1, 2, 3, 4, 5]
total = 0

for i in range(0,len(sequence),1):
    total +=  sequence[i]
print(total)

i = 0
while (i<len(sequence)):
    total +=  sequence[i]
    i = i + 1
print(total)

for value in sequence:
     total += value
print(total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = eval(input('enter a number: '))
#       2 if x < 0:
#       3    print('It\'s negative')
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File ~\AppData\Roaming\jupyterlab-desktop\jlab_server\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
# ...

# %% [markdown]
# #  Built-In Data Structures
#
# o Tuple
#
#     - an immutable Python list
#
# o List
#
#     - lists in Python have a lot of powerful methods
#
# o Dictionary
#
#     - dictionaries in Python are similar to hash tables in other programming languages
#
# o Set
#
#     - Python has a built-in Set object
#
# REFERENCES:
#
# Python List Methods - https://www.programiz.com/python-programming/methods/list
#
# Python Dictionaries - https://realpython.com/python-dicts/
#
# Python Sets         - https://www.geeksforgeeks.org/sets-in-python/

# %%
my_list = ['p','r','o','b','l','e','m']
my_list.remove('p')

# Output: ['r', 'o', 'b', 'l', 'e', 'm']
print(my_list)

# Output: 'o'
print(my_list.pop(1))

# Output: ['r', 'b', 'l', 'e', 'm']
print(my_list)

# Output: 'm'
print(my_list.pop())

# Output: ['r', 'b', 'l', 'e']
print(my_list)

my_list.clear()

# Output: []
print(my_list)

# Changing and adding Dictionary Elements
my_dict = {'name': 'Jack', 'age': 26}

# update value
my_dict['age'] = 27

#Output: {'age': 27, 'name': 'Jack'}
print(my_dict)

# add item
my_dict['address'] = 'Downtown'

# Output: {'address': 'Downtown', 'age': 27, 'name': 'Jack'}
print(my_dict)

# Removing elements from a dictionary

# create a dictionary
squares = {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# remove a particular item, returns its value
# Output: 16
print(squares.pop(4))

# Output: {1: 1, 2: 4, 3: 9, 5: 25}
print(squares)

# remove an arbitrary item, return (key,value)
# Output: (5, 25)
print(squares.popitem())

# Output: {1: 1, 2: 4, 3: 9}
print(squares)

# remove all items
squares.clear()

# Output: {}
print(squares)

# delete the dictionary itself
del squares
