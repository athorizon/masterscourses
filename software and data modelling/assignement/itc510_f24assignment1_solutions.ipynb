# %% [markdown]
# # Assignment 1 - Python and Jupyter (20 points)
# ## Due: 9/6/24 (10pm)
#
# This assignment is desiged to provide a quick review/tutorial on Python as well as how to use Jupyter  Notebooks to integrate code snippets into a single document that can be used for assignments and project reports.
#
# For all problems, when asked to write a function you must include code **within the function** to check for valid input parameter values as well as code that calls the function for multipe test cases with valid **and** invalid actual parameter values.  Do **not** use exception handling (**try/except**) statements.
#
# **Make sure to add a Markdown cell after your code cell for each problem that explains your test cases and results**.
#
# This assignment can be done individually or as a group of up to **three students**. Only one student should turn in the assignment but all students in a group should at least submit a comment indicating who was in their group and specifying who is responsible for turning in the assignment. All members of a group should be able to explain any code that has been turned in by the group.

# %% [markdown]
# ### 1. In the Code cell below, write a function that calculates the distance between of two **integer** points in a plane using the coordinates (x1, y1) and (x2, y2) where the values of the two points are entered by the user and then passed to the function individually as four separate  values.
#
# ### Include your test case code which should contain several calls to your function some of which return successfully and some that return error messages when the function is given invalid input.

# %%
# Distance(x1,y1,x2,y2)
#
# This function takes four integers as input.  The first two integers
# represent the x,y coordinates of a point and the last two integers
# represent the x,y coordindates of a second point.  The function first
# validates that all four inputs are integers.  After validating the input, it
# the function simply calculates and prints the distance between the two
# points using a formula from the Internet.
#
# input: x1, y1 - two integers representing the first  point
#        x2, y2 - two integers representing the second point
# output: None
def Distance (x1,y1,x2,y2):
    if not (type(x1)==int and type(y1)==int and type(x2)==int and type(y2)==int):
        print("Invalid input: All four inputs must be integers.")
    else:
        dist = ((((x2 - x1 )**2) + ((y2-y1)**2) )**0.5)
        print("The distance between [",x1,",",y1,"] and","[",x2,",",y2,"] is:",dist)

a, b, c, d = eval(input("Enter coordinates x1,y1,x2,y2 (separated by commas)"))
Distance(a,b,c,d)

# %% [markdown]
# ## Test case 1 - valid input resulting in correct output
# ### Enter coordinates x1,y1,x2,y2 (separated by commas) 1,2,1,4
# ### The distance between [ 1 , 2 ] and [ 1 , 4 ] is: 2.0
# ###
# ## Test case 2 - valid input (including negative integers and zero) resulting in correct output
# ### Enter coordinates x1,y1,x2,y2 (separated by commas) -10,0,10,0
# ### The distance between [ -10 , 0 ] and [ 10 , 0 ] is: 20.0
# ###
# ## Test case 3 - invalid input (string parameter value) resulting in an error message
# ### Enter coordinates x1,y1,x2,y2 (separated by commas) 'mike',2,3,4
# ### Invalid input: All four inputs must be integers.
# ###
# ## Test case 4 - invalid input (float parameter value) resulting in an error message
# ### Enter coordinates x1,y1,x2,y2 (separated by commas) 1,2,3,4.5
# ### Invalid input: All four inputs must be integers.
#
#
# Invalid input: All four inputs must be integers.

# %% [markdown]
# ### 2.  In the code cell below, write a function that calculates the summation (the sum of the sequence) between two **positive** integers.  The two integers must be passed to the function in a single two-element Python list.  If provided valid input, the function should calculate the summation and return the result of the calculation.
#
# ### Include your test case code.

# %%
def summation(numbers):

    msg = "Input error:\n"
    # Validate that the input is a list, that it contains only two elements, and that the two elements are positive integers
    if not type(numbers) == list:
        msg = msg + "Only a single list can be provided as input.\n"
    elif len(numbers) != 2:
        msg = msg + "Only two element lists can be provided as input.\n"
    elif not (type(numbers[0]) == int and type(numbers[1]) == int):
        msg = msg + "List element values can only be integers.\n"
    elif (numbers[0]) <= 0 or numbers[1] <= 0:
        msg = msg + "List element values must be positive integers.\n"
    else:    # valid input received...calculate and return summation
        # Get the two integers from the list placing the smaller of the two into the start variable
        if numbers[0] <= numbers[1]:
            start = numbers[0]
            end   = numbers[1]
        else:
            start = numbers[1]
            end    = numbers[0]      
        # Calculate the summation between the two integers
        sum = 0
        for i in range(start,end):
            sum = sum + i
        print ("The summation of", start, "to", end, "is:")
        return sum
    return msg    # only excuted if valid sum not returned

# Test cases
print(summation([5,10]))  
print(summation([15,10]))  
print(summation("mike"))
print(summation([1,2,3]))
print(summation([12.5,8.5]))
print(summation([5, -3]))

# %% [markdown]
# ## Test case 1 - valid input
# ### print(summation([5,10]))
# ### The summation of 5 to 10 is:
# ### 35
# ##
# ## Test case 2 - valid input
# ### print(summation([15,10])))
# ### The summation of 15 to 10 is: 60
# ##
# ## Test case 3 - invalid input (non-list parameter)
# ### print(summation("mike"))
# ### Input error:
# ### Only a single list can be provided as input.
# ##
# ## Test case 4 - invalid input (non 2 element list)
# ### print(summation([1,2,3]))
# ### Input error:
# ### Only two element lists can be provided as input.
# ##
# ## Test case 5 - invalid input (non-integer values in list)
# ### print(summation([12.5,8.5]))
# ### Input error:
# ### List element values can only be integers.
# ##
# ## Test case 6 - invalid input (non-positive values in list)
# ### print(summation([5, -3]))
# ### Input error:
# ### List element values must be positive integers.

# %% [markdown]
# ### 3. In the code cell below, write a function that has three formal parameters.   The first parameter must be a list containing only string elements, the second parameter must be a single string and the third parameter should be optional (with a default value of 0) and a non-negative integer.   After validating its input, the function should then replace each string in the list with a new string that overwrites the original string with the string provided as the second input parameter starting at the index provided by the third input parameter.   If the index provided is beyond the index of the last character in the string, then the new string should be concatenated onto the end of the string.   Note: new strings can be longer than the original strings but cannot be shorter.   Additionally, this function MUST NOT return anything but after a successful function call, the array passed to the function should be modified.
#
# ### Include your test case code which should contain several calls to your function some of which return successfully and some that return error messages when the function is given invalid input.
#
# ### Example Input
#
# list = ["mike","johnson","is","my","teacher"]
#
# string = '###'
#
# integer = 2
#
# ### Output of list after function call
#
# ["mi###","jo###on","is###","my###","te###er"]

# %%
# Stringfun(lst,substr,idx=0)
#
# This function takes either two or three inputs.  The first input must
# be a list of strings and the second element must be a string.  The third
# optional input is the index where the given string is to be placed in
# each string in the given list.   After validating the input, the function
# loops through each string in the array and places the given substring
# into each string in the array.  The function does not return anything
# although it will modify the parameter provided list if provided valid input.
#
# input:  lst    - a list of strings
#         substr - a string to be inserted into the strings in the list
#         idx    - optional parameter that indicates starting location for substr
# output: None
def Stringfun(lst,substr,idx=0):
    if not (isinstance(lst, list) and type(substr) == str and type(idx) == int):
        print("Invalid input: must provide list, string, integer (optional)")
    else:
        flag = True  
        for val in lst:    # loop to make sure all list elements are strings
            if not type(val) == str:
                flag = False
                print("Invalid values in the provided list must be strings.")
                break
        if flag == True:
            for i in range(len(lst)):
                tempstr = lst[i]
                lst[i] = tempstr[0:idx] + substr + tempstr[idx+len(substr):]
# Test code
strings = ["onetwo","threefourfive","","sixseveneight","nineten"]
Stringfun(strings,"---")
print("String value after function call:",strings)
strings = ["onetwo","threefourfive","","sixseveneight","nineten"]
Stringfun(strings,"---",2)
print("String value after function call:",strings)
strings = ["onetwo","threefourfive","","sixseveneight","nineten"]
Stringfun(strings,"---",20)
print("String value after function call:",strings)
Stringfun(1,"---",2)
strings = ["one","two"]
Stringfun(strings,[2,2])
print("String value after function call:",strings)
strings = ["one","two"]
Stringfun(strings,[2,2],"mike")
print("String value after function call:",strings)
strings = [1,2]
Stringfun(strings,"---")
print("String value after function call:",strings)

# %% [markdown]
# ## Test case 1 - valid input with no optional parameter
# ### strings = ["onetwo","threefourfive","","sixseveneight","nineten"]
# ### Stringfun(strings,"---")
# ### print("String value after function call:",strings)
# ### String value after function call: ['---two', '---eefourfive', '---', '---seveneight', '---eten']
# ##
# ## Test case 2 - valid input with optional parameter
# ### strings = ["onetwo","threefourfive","","sixseveneight","nineten"]
# ### Stringfun(strings,"---",2)
# ### print("String value after function call:",strings)
# ### String value after function call: ['on---o', 'th---fourfive', '---', 'si---veneight', 'ni---en']
# ##
# ## Test case 3 - valid input with optional parameter that exceeds all string lengths
# ### strings = ["onetwo","threefourfive","","sixseveneight","nineten"]
# ### Stringfun(strings,"---",20)
# ### print("String value after function call:",strings)
# ### String value after function call: ['onetwo---', 'threefourfive---', '---', 'sixseveneight---', 'nineten---']
# ##
# ## Test case 4 - invalid input (first parameter not a list)
# ### Stringfun(1,"---",2)
# ### Invalid input: must provide list, string, integer (optional)
# ##
# ## Test case 5 - invalid input (second parameter not a string)
# ### strings = ["one","two"]
# ### Stringfun(strings,[2,2])
# ### print("String value after function call:",strings)
# ### Invalid input: must provide list, string, integer (optional)
# ### String value after function call: ['one', 'two']
# ##
# ## Test case 6 - invalid input (third parameter not an integer)
# ### strings = ["one","two"]
# ### Stringfun(strings,"---","mike")
# ### print("String value after function call:",strings)
# ### Invalid input: must provide list, string, integer (optional)
# ### String value after function call: ['one', 'two']
# ##
# ## Test case 7 - invalid input (parameter provided list must contain only strings)
# ### strings = [1,2]
# ### Stringfun(strings,"---")
# ### print("String value after function call:",strings)'
# ### Invalid values in the provided list must be strings.
# ### String value after function call: [1, 2]

# %% [markdown]
# ### 4. In the code cell below, write a function that takes as input a large Python list and a positive integer.   The function should iterate through the list and place each element into a Python dictionary if it is not already in the dictionary and give it a value of 1.   If the item is already in the dictionary, then the function should instead increment the value for that item.  The function should not modify the original list but instead should return a newly created list that contains only the elements that appeared in the list the exact same number of times as was specified by the value of the positive integer passed to the function.
#
# ### For this problem, you must first create a text file called "words.txt" that contains at least 100 words.   Then prior to calling your function you must first read in the "words.txt" file and place each "word" in a list that is then passed to passed to your function.
#
# ### Include your test case code which should contain several calls to your function some of which return successfully and some that return error messages when the function is given invalid input.

# %%
# Wordfun(lst,num)
#
# This function takes as input a large Python list of arbitrary elements
# and an integer value that is used to specify which words to return 
# in a list containing all of the elements in the original list
# that appeared in the list exactly than number of times.  The function utilizes
# a Python dictionary to count the number of occurrences of each word.
#
# input:  lst    - a list of arbitrary elements
#         num    - an integer representing the value that will be used to determine which words to return
# output: retlst - a list of elements which appeared at least three times in the original list

def Wordfun(lst,num):
    retlst  = []  # initialize return
    if not isinstance(lst, list):
        print("Invalid input: must provide a list as input")
    elif type(num) != int or num < 1:
        print("Invalid input: number provided must be a positive integer")
    else:
        dictwords = {}  # initialize dictionary
        for val in lst:
            if val in dictwords:
                dictwords[val] = dictwords[val] + 1
            else:
                dictwords[val] = 1
        for key in dictwords:
            if (dictwords[key] >= num):
                retlst.append(key)
    return retlst

# Test code
cnt = 36
f1=open("words.txt","r")  # need to have a words.txt file in same folder
lst=f1.read().split(",")  # words in file stored as a single comma-separated string

# Hardcoced string for testing purposes
#str = "apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini, apple, banana, cherry, date, elderberry, fig, grape, honeydew, kiwi, lemon, mango, nectarine, orange, papaya, quince, raspberry, strawberry, tangerine, ugli, vanilla, watermelon, xigua, yam, zucchini"
# lst = str.split(",") 

Wordfun("mike",cnt)                 # Test case 1 
Wordfun(lst,"mike")                 # Test case 2 
#lst = [1,2,3,2,3,2,1,"a","b","c","a","b","c","a","b"]   # Test case 3
#result = Wordfun(lst,cnt) 

result = Wordfun(lst,cnt)   
print("The following list contains all the words in the file that appeared exactly",cnt,"times from the given input file: ")
print(result)
print()
print("These are all the words as they appeared in the original list")
print(lst)
# Out:
# Invalid input: must provide a list as input
# Invalid input: number provided must be a positive integer
# The following list contains all the words in the file that appeared exactly 36 times from the given input file:
# [' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini']
#
# These are all the words as they appeared in the original list
# ...

# %% [markdown]
# ### [' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple']

# %% [markdown]
# ## This program was successfully tested with a text file called "words.txt" which contains 864 words separated by commas.   Instead of attaching that file, I have included a commented hardcoded string containing the words as well as the output from the exectution in the final test case below:
#
# ## Test case 1 - Invalid input (first parameter value provided to  function is not a list)
# ### Wordfun("mike",cnt) # Test case 1
# ### Invalid input: must provide a list as inputr
# ##
# ## Test case 2 - Invalid input (second parameter value provided to function is not a positive integer)
# ### Wordfun(lst,"mike") # Test case
# ### Invalid input: number provided must be a positive integer2
# ##
# ## Test case 3 - Valid with combination of strings and numbers (program should work for this case)
# ### lst = str.split(",")
# ### lst = [1,2,3,2,3,2,1,"a","b","c","a","b","c","a","b"]
# ### result = Wordfun(lst)   # Test case 3
# #### These are all the words as they appeared in the original list
# #### [1, 2, 3, 2, 3, 2, 1, 'a', 'b', 'c', 'a', 'b', 'c', 'a', 'b']
# ##
# ## Test case 4 - Valid with large text file: "words.txt
# ### result = Wordfun(lst)   # Test case 3"
# #### The following list contains all the words in the file that appeared exactly 36 times from the given input file:
# ##### [' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple']
# ##
# #### These are all the words as they appeared in the original list
# ##### ['apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini', ' apple', ' banana', ' cherry', ' date', ' elderberry', ' fig', ' grape', ' honeydew', ' kiwi', ' lemon', ' mango', ' nectarine', ' orange', ' papaya', ' quince', ' raspberry', ' strawberry', ' tangerine', ' ugli', ' vanilla', ' watermelon', ' xigua', ' yam', ' zucchini']
