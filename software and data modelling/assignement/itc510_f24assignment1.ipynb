# %% [markdown]
# # Assignment 1 - Python and Jupyter (20 points)
# ## Due: 9/6/24 (10pm)
#
# This assignment is desiged to provide a quick review/tutorial on Python as well as how to use Jupyter  Notebooks to integrate code snippets into a single document that can be used for assignments and project reports.
#
# For all problems, when asked to write a function you must include code **within the function** to check for valid input parameter values as well as code that calls the function for multipe test cases with valid **and** invalid actual parameter values.  Do **not** use exception handling (**try/except**) statements.
#
# **Make sure to add a Markdown cell after your code cell for each problem that explains your test cases and results**.
#
# This assignment can be done individually or as a group of up to **three students**. Only one student should turn in the assignment but all students in a group should at least submit a comment indicating who was in their group and specifying who is responsible for turning in the assignment. All members of a group should be able to explain any code that has been turned in by the group.

# %% [markdown]
# ### 1. In the Code cell below, write a function that calculates the distance between of two **integer** points in a plane using the coordinates (x1, y1) and (x2, y2) where the values of the two points are entered by the user and then passed to the function individually as four separate  values.
#
# ### Include your test case code which should contain several calls to your function some of which return successfully and some that return error messages when the function is given invalid input.

# %%
import math as M

#single input function to take an integer inputs only. will ask user to enter valid input and will finish only on valid input
# def takeIntInput(inputName):
#     while(True):
#         try:
#             x1=eval(input('Please Enter '+ inputName +' : '))
#         except:
#             print("the value entered should be numeric")
#         else:
#             return x1
def checkInput(inCoord):
    #inCoord = input("Please enter ',' seperated x1,y1,x2,y2 coordinates")
    if(inCoord is None):
        print(f"the list passed is {inCoord}")
        return
    if(not type(inCoord)==str):
        print(f"the list passed {inCoord} is of type {type(inCoord)} and was expected of type str")
        return
    inputList = inCoord.split(',')
    length = len(inputList)
    if(length<4):
        print("please provide 4 coordinates value in form of ',' seperated x1,y1,x2,y2 coordinates, you have provided "+str(length)+" values")
        return
    if(length>4):
        print("you have entered extra coordinates, only first 4 entered values will be considered for calculations : "+str(inputList[0:4])+" and remaining are not checked")
    #print("inputlist : "+str(inputList))
    pos=0;
    for val in inputList[0:4]:
        if(val.isnumeric()):
            inputList[pos]=int(val)
            pos+=1
        elif(val[1:].isnumeric()):
            inputList[pos]=int(val)
            pos+=1
        else:
            print(f"the enter coordinate : {val} is an invalid input. Please enter the values again")
            return
        # try:
        #     coor=eval(val)
        # except:
        #     print("the enter coordinate : "+str(val)+" is an invalid input. Please enter the values again")
        #     return
        # else:
        #     inputList[pos] = coor
        #     pos+=1
    return inputList
def calDistance(A,B):
    try:
        dis = M.sqrt((B[0]-A[0])**2 + (B[1]-A[1])**2)
    except:
        print("some error occured while calculating distance, Please try again entering inputs")
    else:
        return dis

#primary functions
def calculateDistance(input):
    checkedList = checkInput(input)
    if(checkedList is not None):
        # print(checkedList)
        A=[checkedList[0],checkedList[1]]
        B=[checkedList[2],checkedList[3]]
        print("entered coordinates are : A = "+str(A)+" B = "+str(B))
        dis = round(calDistance(A,B),2)
        print("distance between A"+str(A)+" and B"+str(B)+" is : "+str(dis))


# inCoord = input("Please enter ',' seperated x1,y1,x2,y2 coordinates")
# calculateDistance(inCoord)

# %% [markdown]
# ### The function calculateDistance(input) takes a string input with comma seperated numerical values, the String should contain 4 numerical value in form of "x1,y1,x2,y2" and then a distance is calculated between two points [x1,y1] and [x2,y2] and returned as distance value.
#
# ### The calculateDistance(input) once gets the input in for string, it will first validate if the value passed is indeed a str type, shouldn't be None. If anything fails then the function return after printing a respective message. After the validation passes, it splits the string based on ',' delimiter, and then check for the length of the resultant list, the list should be atleast of length 4 otherwise the function return, if it is greater then 4, it will only consider the first 4 elements. The function will check accept string literal in the list if they are valid numerical values and calculates the distance if necessary conversions are required and returns the value.
#
# **Test 1: Happy flow**<br>
# This is a happy flow and returns a distance for the input "1,2,2,1".
#
# **Test 2: inputs are less then 4 for input: "1,2,2"**<br>
# This input fails as the input has less then 4 values, and this print a message : "please provide 4 coordinates value in form of ',' seperated x1,y1,x2,y2 coordinates, you have     provided 3 values".
#
# **Test 3: input has more then 4 values for input "1,2,2,1,1"**<br>
# This works fine as it has atleast 4 input values to work with, but it will print a warning message: "you have entered extra coordinates, only first 4 entered values will be        considered for calculations : ['1', '2', '2', '1'] and remaining are not checked" as anything after 4 values are not considered whether they are valid or not. This will then       return the distance value calculated.
#
# **Test 4: input has negative values with input "-1,1,4,-5"**<br>
# This works fine as negative values are acceptable coordinates and the function returns the calculated distance.
#
# **Test 5: input has float values for input "5.67,2.1,2,0"**<br>
# This test will fail as floating values are not acceptable coordinates and the function will print the message: "the enter coordinate : 5.67 is an invalid input. Please enter       the values again".
#
# **Test 6: input has non numerical value with input "100,hello,10,1"**<br>
# This will fail as one of the value 'hello' is not an acceptable input value and the function will print the message: "the enter coordinate : hello is an invalid input. Please      enter the values again".
#
# **Test 7: input has non numerical value but outside of acceptable limit with input "12,34,1,44,hello"**<br>
# This test will work fine as the first 4 values in the input are all acceptable values and the remaining values are not checked. The function will print a warning message: "you have entered extra coordinates, only first 4 entered values will be considered for calculations : ['12', '34', '1', '44'] and remaining are not checked" and will then calculate and return the distance between the valid coordinates
#
# **Test 8: input is empty**<br>
# This Test will fail in validation as the input string is empty. The function will print the message: "the list passed is None"
#
# **Test 9: input is not in string type for input 100**<br>
# This Test will fail as the input is expected to be string value and any other value passed will not be considered, for above input the function will print the message: "the list passed 100 is of type <class 'int'> and was expected of type str"

# %%
#Test Cases for problem 1:
print("test1 : Happy flow")
input="1,2,2,1"
print(f"input is : {input}")
calculateDistance(input)
print()
print()

print("test2 : inputs are less then 4")
input="1,2,2"
print(f"input is : {input}")
calculateDistance(input)
print()
print()

print("test3 : input has more then 4 values")
input="1,2,2,1,1"
print(f"input is : {input}")
calculateDistance(input)
print()
print()

print("test4 : input has negative values")
input="-1,1,4,-5"
print(f"input is : {input}")
calculateDistance(input)
print()
print()

print("test5 : input has float values")
input="5.67,2.1,2,0"
print(f"input is : {input}")
calculateDistance(input)
print()
print()

print("test6 : input has non numerical value")
input="100,hello,10,1"
print(f"input is : {input}")
calculateDistance(input)
print()
print()

print("test7 : input has non numerical value but outside of acceptable limit")
input="12,34,1,44,hello"
print(f"input is : {input}")
calculateDistance(input)
print("\n\n")

print("test8 : input is empty")
input=None
print(f"input is : {input}")
calculateDistance(input)
print("\n\n")

print("test9 : input is not in string type")
input=100
print(f"input is : {input}")
calculateDistance(input)

##test cases for none
# Out:
# test1 : Happy flow
# input is : 1,2,2,1
# entered coordinates are : A = [1, 2] B = [2, 1]
# distance between A[1, 2] and B[2, 1] is : 1.41
#
#
# test2 : inputs are less then 4
# input is : 1,2,2
# please provide 4 coordinates value in form of ',' seperated x1,y1,x2,y2 coordinates, you have provided 3 values
#
#
# test3 : input has more then 4 values
# input is : 1,2,2,1,1
# you have entered extra coordinates, only first 4 entered values will be considered for calculations : ['1', '2', '2', '1'] and remaining are not checked
# entered coordinates are : A = [1, 2] B = [2, 1]
# distance between A[1, 2] and B[2, 1] is : 1.41
#
#
# test4 : input has negative values
# input is : -1,1,4,-5
# entered coordinates are : A = [-1, 1] B = [4, -5]
# distance between A[-1, 1] and B[4, -5] is : 7.81
#
#
# test5 : input has float values
# input is : 5.67,2.1,2,0
# the enter coordinate : 5.67 is an invalid input. Please enter the values again
#
#
# test6 : input has non numerical value
# ...

# %% [markdown]
# ### 2.  In the code cell below, write a function that calculates the summation (the sum of the sequence) between two **positive** integers.  The two integers must be passed to the function in a single two-element Python list.  If provided valid input, the function should calculate the summation and return the result of the calculation.
#
# ### Include your test case code.

# %%
def sumSequence(inVal):

    if(inVal is None):
        print(f"the value provided is {inVal}")
        return
    if(type(inVal) !=list):
        print(f"the value of {inVal} and is of type {type(inVal)}")
        return
    # inputList = inVal.split(',')
    inputList=inVal
    length = len(inputList)
    if(length<2):
        print("Please provide two valid integer values")
        return
    if(length>2):
        print(f"you have entered {length} values, only first 2 entered values will be considered for calculations : {inputList[0:2]} and remaining are not checked")
    #print("inputlist : "+str(inputList))
    pos=0;
    for val in inputList[0:2]:
        value=0
        if(type(val)==str):
            if(val.isnumeric()):
                value=int(val)
            elif(val[1:].isnumeric()):
                value=int(val)
            elif(val.isdecimal()):
                value=float(val)
            elif(val[1:].isdecimal()):
                value=float(val)
            else:
                print(f"the enter coordinate : {val} is an invalid input. Please enter the values again")
                return
        elif(type(val)==int or type(val)==float):
            value=val
        else:
            print(f"the enter coordinate : {val} is an invalid input. Please enter the values again")
            return
        if(value<0):
            print(f"the {value} is negative and is not accepted, please try again")
            return
        inputList[pos] = value
        pos+=1
    print(f"sum is : {inputList[0]+inputList[1]}")

# print(f"sum is : {sumSequence([1,2])}")

# %% [markdown]
# ### The function sumSequence(list) accepts a list with numerical values with at least 2 elements in it. The function will validate the list paramater, if it of type list and it is not None. after the these validation are completed, It will check for the length of the list as at least 2 elements are required or if there are more then 2 elements, then others will be ignored. The function will then check the elements and accepts if they are string only if they can be resolved to a valid integer or floating value and checks if the value is non negative. All validation errors will print a message and function return or will return the sum as result.
#
# **Test 1: Happy flow**<br>
# This is a happy flow and returns the sum calculated.
#
# **Test 2: when negative values are passed for input: [-12,34]**<br>
# This input fails as the input has negative values, and this print a message : "the -12 is negative and is not accepted, please try again".
#
# **Test 3: when the input is empty **<br>
# This will fail as the input is empty and the function will print the message: "the value provided is None"
#
# **Test 4: when more then two values are passed in the input list with input [73,93,-1]**<br>
# This works fine as the first two values passed are valid and all the values after that are not considered even if they are valid or invalid. The function will print the sum
#
# **Test 5:  when less then 2 values are passed in the input string for input [23]**<br>
# This test will fail as the input list has only one element and atleast 2 elements are expected so the function will print the message: "Please provide two valid integer values".
#
# **Test 6: when the not in form of List with input "1"**<br>
# This will fail as the value passed is of type string and the function will print the message: "the value of 1 and is of type <class 'str'>".
#
# **Test 7: when the input in the list is of type string but of numerical value with input ['1','2']**<br>
# This test will work fine as the input value although are of string type, they can be resolved to a numerical value so the function will return the calculated sum

# %%
##test cases for none

print("test1 : Happy flow")
input=[12,34]
print(f"input is : {input}")
sumSequence(input)
print("\n\n")

print("test2 : when negative values are passed")
input=[-12,34]
print(f"input is : {input}")
sumSequence(input)
print("\n\n")

print("test3 : when the input is empty")
input=None
print(f"input is : {input}")
sumSequence(input)
print("\n\n")

print("test4 : when more then two values are passed in the input string")
input=[73,93,-1]
print(f"input is : {input}")
sumSequence(input)
print("\n\n")

print("test5 : when less then 2 values are passed in the input string")
input=[23]
print(f"input is : {input}")
sumSequence(input)
print("\n\n")

print("test6 : when the input is not in form of List")
input="1"
print(f"input is : {input}")
sumSequence(input)
print("\n\n")

print("test6 : when the input in the list is of type string but of numerical value ")
input=['1','2']
print(f"input is : {input}")
sumSequence(input)
print("\n\n")
# Out:
# test1 : Happy flow
# input is : [12, 34]
# sum is : 46
#
#
#
# test2 : when negative values are passed
# input is : [-12, 34]
# the -12 is negative and is not accepted, please try again
#
#
#
# test3 : when the input is empty
# input is : None
# the value provided is None
#
#
#
# test4 : when more then two values are passed in the input string
# input is : [73, 93, -1]
# you have entered 3 values, only first 2 entered values will be considered for calculations : [73, 93] and remaining are not checked
# sum is : 166
#
#
#
# test5 : when less then 2 values are passed in the input string
# input is : [23]
# Please provide two valid integer values
#
#
#
# test6 : when the input is not in form of List
# input is : 1
# the value of 1 and is of type <class 'str'>
#
#
#
# test6 : when the input in the list is of type string but of numerical value
# input is : ['1', '2']
# sum is : 3

# %% [markdown]
# ### 3. In the code cell below, write a function that has three formal parameters.   The first parameter must be a list containing only string elements, the second parameter must be a single string and the third parameter should be optional (with a default value of 0) and a non-negative integer.   After validating its input, the function should then replace each string in the list with a new string that overwrites the original string with the string provided as the second input parameter starting at the index provided by the third input parameter.   If the index provided is beyond the index of the last character in the string, then the new string should be concatenated onto the end of the string.   Note: new strings can be longer than the original strings but cannot be shorter.   Additionally, this function MUST NOT return anything but after a successful function call, the array passed to the function should be modified.
#
# ### Include your test case code which should contain several calls to your function some of which return successfully and some that return error messages when the function is given invalid input.
#
# ### Example Input
#
# list = ["mike","johnson","is","my","teacher"]
#
# string = '###'
#
# integer = 2
#
# ### Output of list after function call
#
# ["mi###","jo###on","is###","my###","te###er"]

# %%
def stringReplace(strList: list, strReplacement: str, index = 0):
    if(not checkListForString(strList)):
        print(f"some or all elements in the list are not of string type or list is Null, please recheck list : {strList}")
        return
    if(strReplacement is None or type(strReplacement)!=str):
        print(f"the replacement string should be a string value, currently it is {strReplacement}")
        return
    if(index is None):
        print(f"the Index value : {index} is not a acceptable value, please try again with correct input")
        return
    else:
        if(type(index)==str and not index.isnumeric):
            print(f"Index value : {index} is not an acceptable value")
            return
        else:
            index = int(index)
        if(index<0):
            print(f"Index value : {index} is not an acceptable value")
            return
    pos=0
    for value in strList:
        if(index>=len(value)):
            strList[pos] = value+strReplacement
        else:
            strList[pos] = value.replace(value[index:index+len(strReplacement)],strReplacement)
        pos+=1
    return strList
    
def checkListForString(strList):
    if(strList is None):
        return False
    if(len(strList) == 0):
        return False
    for string in strList:
        if(not string.isalpha()):
            return False
    return True
strList = ["mike","johnson","is","my","teacher"]
# stringReplace(strList,"123",'1')
# print(strList)

# %% [markdown]
# ### The function stringReplace(list, replacementString, indexes) will accept a list of values, a replacement string and index from which the replacement will start with a default value of 0. after proper validations for each parameter passed to verify the type and None, it will return a list with each element of the list being concatenated and replaced by the replacement string starting from the index value. The Function can accept only two parameters as well, as the index is default to value 0 if not passed.
#
# **Test 1: Happy flow**<br>
# inputs <br>
#  List : ['mike', 'johnson', 'is', 'my', 'teacher'] <br>
#  replacement : "123" <br>
#  index : 1<br>
#   This test will return the updated list with each element replaced
#
# **Test 2: When the list passed is empty**<br>
# inputs <br>
#  List : None <br>
#  replacement : "123" <br>
#  index : 1<br>
#  This test will fail as the entered list is empty and the function will print the message: "some or all elements in the list are not of string type or list is Null, please recheck list : None"
#
# **Test 3: when the replacement string is None**<br>
# inputs <br>
#  List : ['mike', 'johnson', 'is', 'my', 'teacher'] <br>
#  replacement : None <br>
#  index : 1<br>
#  This test will fail as the replacement string is None and the function will print a message: "the replacement string should be a string value, currently it is None"
#
# **Test 4: when the index value is None**<br>
# inputs <br>
#  List : ['mike', 'johnson', 'is', 'my', 'teacher'] <br>
#  replacement : "123" <br>
#  index : None<br>
#  This Test will fail as the index value passed is None and the function will print the message: "the Index value : None is not a acceptable value, please try again with correct input"
#
# **Test 5: when the list passed is an empty list**<br>
# inputs <br>
#  List : [] <br>
#  replacement : "123" <br>
#  index : 1<br>
#  This Test will fail as the List passed is an empty list and no operations can be performed so the function will print the message: "some or all elements in the list are not of string type or list is Null, please recheck list : []"
#
# **Test 6: when we don't provide any input for the index parameter**<br>
# inputs <br>
#  List : ['mike', 'johnson', 'is', 'my', 'teacher'] <br>
#  replacement : "123" <br>
#  index : no input<br>
#  This test will pass as no input for the index will take a default value of 0 and the function will return the list with the valid replacements
#
# **Test 7: When the Index value is greater then any the size of the length of values in the list**<br>
# inputs <br>
#  List : ['mike', 'johnson', 'is', 'my', 'teacher'] <br>
#  replacement : "123" <br>
#  index : 1000<br>
#  This test will pass as this is a valid condition. Larger index value will mean that the replacement string will be concatenated at the end of the string value. The function will return the valid list with the replacements
#
# **Test 8: When the replacement string is not of str type**<br>
# inputs <br>
#  List : ['mike', 'johnson', 'is', 'my', 'teacher'] <br>
#  replacement : 123 <br>
#  index : 1<br>
#  This Test will fail as the replacement string is not of str type, the function will print a message: "the replacement string should be a string value, currently it is 123"

# %%
print("test1")
strList = ["mike","johnson","is","my","teacher"]
print(f"inputs \n List : {strList} \n replacement : \"123\" \n index : 1")
stringReplace(strList,"123",1)
print(f"List after replacement : {strList}")
print("\n\n")

print("test2")
strList = None
print(f"inputs \n List : {strList} \n replacement : \"123\" \n index : 1")
stringReplace(strList,"123",1)
print(f"List after replacement : {strList}")
print("\n\n")

print("test3")
strList = ["mike","johnson","is","my","teacher"]
print(f"inputs \n List : {strList} \n replacement : None \n index : 1")
stringReplace(strList,None,1)
print(f"List after replacement : {strList}")
print("\n\n")

print("test4")
strList = ["mike","johnson","is","my","teacher"]
print(f"inputs \n List : {strList} \n replacement : \"123\" \n index : None")
stringReplace(strList,"123",None)
print(f"List after replacement : {strList}")
print("\n\n")

print("test5")
strList = []
print(f"inputs \n List : {strList} \n replacement : \"123\" \n index : 1")
stringReplace(strList,"123",1)
print(f"List after replacement : {strList}")
print("\n\n")

print("test6")
strList = ["mike","johnson","is","my","teacher"]
print(f"inputs \n List : {strList} \n replacement : \"123\" \n index : no input")
stringReplace(strList,"123")
print(f"List after replacement : {strList}")
print("\n\n")

print("test7")
strList = ["mike","johnson","is","my","teacher"]
print(f"inputs \n List : {strList} \n replacement : \"123\" \n index : 1000")
stringReplace(strList,"123",1000)
print(f"List after replacement : {strList}")
print("\n\n")

print("test8")
strList = ["mike","johnson","is","my","teacher"]
print(f"inputs \n List : {strList} \n replacement : 123 \n index : 1")
stringReplace(strList,123,1)
print(f"List after replacement : {strList}")
print("\n\n")
# Out:
# test1
# inputs
#  List : ['mike', 'johnson', 'is', 'my', 'teacher']
#  replacement : "123"
#  index : 1
# List after replacement : ['m123', 'j123son', 'i123', 'm123', 't123her']
#
#
#
# test2
# inputs
#  List : None
#  replacement : "123"
#  index : 1
# some or all elements in the list are not of string type or list is Null, please recheck list : None
# List after replacement : None
#
#
#
# test3
# inputs
#  List : ['mike', 'johnson', 'is', 'my', 'teacher']
#  replacement : None
#  index : 1
# the replacement string should be a string value, currently it is None
# List after replacement : ['mike', 'johnson', 'is', 'my', 'teacher']
#
#
#
# test4
# inputs
#  List : ['mike', 'johnson', 'is', 'my', 'teacher']
#  replacement : "123"
#  index : None
# the Index value : None is not a acceptable value, please try again with correct input
# List after replacement : ['mike', 'johnson', 'is', 'my', 'teacher']
#
#
#
# test5
# inputs
#  List : []
#  replacement : "123"
#  index : 1
# ...

# %% [markdown]
# ### 4. In the code cell below, write a function that takes as input a large Python list and positive integer.   The function should iterate through the list and place each element into a Python dictionary if it is not already in the dictionary and give it a value of 1.   If the item is already in the dictionary, then the function should instead increment the value for that item.  The function should not modify the original list but instead should return a newly created list that contains only the elements that appeared in the list the exact same number of times as was specified by the value of the positive integer passed to the function.
#
# ### For this problem, you must first create a text file called "words.txt" that contains at least 100 words.   Then prior to calling your function you must first read in the "words.txt" file and place each "word" in a list that is then passed to passed to your function.
#
# ### Include your test case code which should contain several calls to your function some of which return successfully and some that return error messages when the function is given invalid input.

# %%
def filetoList(ifile):
    try:
        infile = open(ifile, "rt")
        names = infile.read()
        return names.split(",")
    except(FileNotFoundError):
        print("file does not exist")
        
wordslistfromfile = filetoList("words.txt")
print(f"the list is \n{wordslistfromfile}")
# Out:
# the list is
# ...

# %%
def filetoList(ifile):
    try:
        infile = open(ifile, "rt")
        names = infile.read()
        return names.split(",")
    except(FileNotFoundError):
        print("file does not exist")
def dicCreator(inlist,printdict):
    pos=0
    wordDict = {}
    for val in inlist:
        val=val.strip()
        if(wordDict.get(val) is None):
            wordDict[val] = 1
        else:
            wordDict[val]=wordDict[val]+1
    if(printdict):
        print(f"the created dict is : \n {wordDict}")
    return wordDict
# ifile = input("Enter input file name  -> ")
# dictCreator(ifile)
def wordFrequency(inList, x, printdict=False):
    if(inList is None):
        print(f"the list is None")
        return
    if(type(inList)!=list):
        print(f"the list passed is not of valid type")
        return
    if(len(inList)<=0):
        print(f"the list is empty")
        return 
    if(x is None):
        print(f"the integer value is None")
        return
    if(type(x)!=int):
        print(f"integer value {x} is of type {type(x)} but expected to be int")
        return
    if(x<=0):
        print(f"integer value {x} is not an acceptable value, please enter a valid value greater then 1")
        return
    returnList=[]
    wordDict=dicCreator(inList,printdict)
    for val in wordDict.keys():
        if(wordDict.get(val) == x):
            returnList.append(val)
    print(returnList)
# wordFrequency(wordslistfromfile,2)
# wordFrequency(None,2)
# wordFrequency(wordslistfromfile,None)
# wordFrequency(wordslistfromfile,'2')
# wordFrequency(wordslistfromfile,-2)
# wordFrequency([],0)

# %% [markdown]
# ### The function wordFrequency(wordlist,integer) where wordlist is the list of the words passed as a list, and the integer value is the frequency of words to be checked from the list, the function will create a dictionary from the list first with the names as key and the frequency as the value. Then it will check each key value if it matches the integer value passed and when it matches, it will append the word into a new list. After the loop finishes all the words with the frequency same as integer value are appended in the list and returned.
#
# ### There is another function filetoList(filelocation) which accepts a file location as returns a list of all the words inside the file, which is used to assign the variable wordslistfromfile the list which is then used as the primary parameter
#
#
# **Test 1: Happy flow**<br>
# This test works fine and returns the the list with words appearing 2 times
#
# **Test 2: When the list passed is of None**<br>
# This test will fail as the list is None and the function will print the message: "the list is None"
#
# **Test 3: When the Integer value passed is None**<br>
# This test will fail as the the Integer passed is None and the function will print the message: "the integer value is None"
#
# **Test 4: When the Integer value passed is not of type integer**<br>
# This test will fail as the integer value is not of integer type and the function will print the message: "integer value 2 is of type <class 'str'> but expected to be int"
#
# **Test 5: When the Integer value passed is a negative value**<br>
# This test will fail as the negative values are not acceptable hence the function will print the message: "integer value -2 is not an acceptable value, please enter a valid value greater then 1"
#
# **Test 6: When the list passed is empty**
# This test will fail as the list passed is empty and the function will print the message: "the list is empty"

# %%
print(f"Test 1 : Happy Flow")
print(f"inputs \n list : wordslistfromfile \n integer : 2")
print("output list is :")
wordFrequency(wordslistfromfile,2)
print("\n\n")

print(f"Test 1 : When the list passed is of None")
print(f"inputs \n list : None \n integer : 2")
print("output list is :")
wordFrequency(None,2)
print("\n\n")

print(f"Test 1 : When the Integer value passed is None")
print(f"inputs \n list : wordslistfromfile \n integer : None")
print("output list is :")
wordFrequency(wordslistfromfile,None)
print("\n\n")

print(f"Test 1 : When the Integer value passed is not of type integer")
print(f"inputs \n list : wordslistfromfile \n integer : '2'")
print("output list is :")
wordFrequency(wordslistfromfile,'2')
print("\n\n")

print(f"Test 1 : When the Integer value passed is a negative value")
print(f"inputs \n list : wordslistfromfile \n integer : -2")
print("output list is :")
wordFrequency(wordslistfromfile,-2)
print("\n\n")

print(f"Test 1 : When the list passed is empty")
print(f"inputs \n list : [] \n integer : 2")
print("output list is :")
wordFrequency([],0)
print("\n\n")
# Out:
# Test 1 : Happy Flow
# inputs
#  list : wordslistfromfile
#  integer : 2
# output list is :
# ['unicorn', 'moon', 'quartz', 'grape', 'flamingo', 'underwater', 'jellyfish', 'mountain', 'cactus', 'forest', 'horizon', 'meteor', 'diamond', 'quail']
#
#
#
# Test 1 : When the list passed is of None
# inputs
#  list : None
#  integer : 2
# output list is :
# the list is None
#
#
#
# Test 1 : When the Integer value passed is None
# inputs
#  list : wordslistfromfile
#  integer : None
# output list is :
# the integer value is None
#
#
#
# Test 1 : When the Integer value passed is not of type integer
# inputs
#  list : wordslistfromfile
#  integer : '2'
# output list is :
# integer value 2 is of type <class 'str'> but expected to be int
#
#
#
# Test 1 : When the Integer value passed is a negative value
# inputs
#  list : wordslistfromfile
#  integer : -2
# output list is :
# integer value -2 is not an acceptable value, please enter a valid value greater then 1
#
#
#
# ...
